# %%
import os
import random
import time
import timm
import xml.etree.ElementTree as ET

import cv2
import matplotlib.pyplot as plt
import numpy
import torch
import torch.nn as nn
import torchvision
from PIL import Image
from sklearn.model_selection import train_test_split
from torch.nn import functional as F
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms

# %%
def extract_data_from_xml(root_dir):
    xml_path = os.path.join(root_dir, "words.xml")
    tree = ET.parse(xml_path)
    root = tree.getroot()

    image_path = []
    image_size = []
    image_label = []
    image_bb = []

    for img in root:
        bbs_of_img = []
        labels_of_img = []

        image_path.append(img[0].text)
        image_size.append((int(img[1].attrib['x']),
                           int(img[1].attrib['y'])))

        for bbs in img.findall('taggedRectangles'):
            for bb in bbs:

                if not bb[0].text.isalnum():
                    continue
                if "é" in bb[0].text.lower() or "ñ" in bb[0].text.lower():
                    continue

                bbs_of_img.append(
                    [
                        float(bb.attrib['x']),
                        float(bb.attrib['y']),
                        float(bb.attrib['width']),
                        float(bb.attrib['height'])
                    ]
                )
                labels_of_img.append(bb[0].text.lower())
        image_label.append(labels_of_img)
        image_bb.append(bbs_of_img)

    return image_path, image_size, image_label, image_bb

# %%
data_dir = "/content/dataset/SceneTrialTrain"
image_path, image_size, image_label, image_boxes = extract_data_from_xml(data_dir)

print("Image path: ", image_path[0])
print("Image size: ", image_size[0])
print("Image label: ", image_label[0])
print("Image boxes: ", image_boxes[0])
# Out:
# Image path:  apanar_06.08.2002/IMG_1261.JPG
# Image size:  (1600, 1200)
# Image label:  ['self', 'adhesive', 'address', 'labels', '36', '89m', 'cls', '250', 'on', 'a', 'roll']
# Image boxes:  [[174.0, 392.0, 274.0, 195.0], [512.0, 391.0, 679.0, 183.0], [184.0, 612.0, 622.0, 174.0], [863.0, 599.0, 446.0, 187.0], [72.0, 6.0, 95.0, 87.0], [247.0, 2.0, 197.0, 88.0], [792.0, 0.0, 115.0, 81.0], [200.0, 848.0, 228.0, 139.0], [473.0, 878.0, 165.0, 109.0], [684.0, 878.0, 71.0, 106.0], [806.0, 844.0, 218.0, 141.0]]

# %%
def split_bounding_boxes(image_paths, image_labels, image_bbs, root_dir, save_dir):
    os.makedirs(save_dir, exist_ok=True)
    count = 0
    labels = []
    for image_path, image_label, image_bb in zip(image_paths, image_labels, image_bbs):
        image = Image.open(os.path.join(root_dir, image_path))

        for label, bb in zip(image_label, image_bb):
            image_cropped = image.crop((bb[0], bb[1], bb[0] + bb[2], bb[1] + bb[3]))
            print(np.mean(image_cropped))
            print(image_cropped.size)

            if np.mean(image_cropped) < 35 or np.mean(image_cropped) > 220:
                continue

            if image_cropped.size[0] < 10 or image_cropped.size[1] < 10:
                continue

            file_name = f"{count:06d}.jpg"
            image_cropped.save(os.path.join(save_dir, file_name))
            new_path = os.path.join(save_dir, file_name)
            label = new_path + "\t" + label
            labels.append(label)

            count += 1
    print(f"Create {count} images")

    with open(os.path.join(save_dir, "labels.txt"), 'w') as f:
        for label in labels:
            f.write(f"{label}\n")



split_bounding_boxes(image_paths=image_path, image_labels=image_label, image_bbs=image_boxes, root_dir=data_dir, save_dir="dataset_text_recognition")
# Out:
# 179.74366460789818
# (274, 195)
# 174.3938906191737
# (679, 183)
# 168.40684788902442
# (622, 174)
# 160.04178956539812
# (446, 187)
# 200.70364992942126
# (95, 87)
# 229.7518843254884
# (197, 88)
# 238.98457684737878
# (115, 81)
# 208.23240355084354
# (228, 139)
# 205.55492540079695
# (165, 109)
# 197.1346886349544
# (71, 106)
# 210.4765328475069
# (218, 141)
# 172.5817728782845
# (847, 172)
# 167.66635515550965
# (502, 81)
# 169.0295499800876
# (540, 31)
# 155.38473713428533
# (409, 69)
# 161.01171706728698
# (265, 73)
# 160.42351492767006
# (57, 19)
# 135.28183421516755
# (63, 15)
# 155.9980694980695
# (111, 14)
# 159.51071428571427
# (70, 16)
# 152.62282282282283
# (74, 15)
# 128.28710089399743
# (145, 18)
# 128.42938468992247
# (64, 43)
# 123.4662568306011
# (61, 40)
# 175.6451133407655
# (138, 52)
# 176.71166276346605
# (350, 61)
# 160.43034722222222
# (64, 75)
# 176.21172516803585
# (103, 52)
# 164.99279388647648
# (363, 59)
# 183.9180614394518
# (374, 77)
# 183.0517496853814
# (644, 102)
# 178.4957264957265
# (99, 26)
# 187.4148148148148
# (85, 27)
# 184.22317188983857
# (54, 26)
# 179.11131313131312
# (132, 25)
# 170.94799741602068
# (43, 24)
# 165.47976190476192
# (70, 28)
# 156.6883116883117
# (77, 21)
# 184.45608605953433
# (87, 26)
# 176.87695652173912
# (100, 23)
# 188.50416198197132
# (393, 86)
# 169.76212009675044
# (257, 37)
# 151.53370596205963
# (82, 24)
# 182.9896855345912
# (53, 25)
# 180.74608695652174
# (92, 25)
# 166.0092272202999
# (34, 17)
# 181.47555883075412
# (59, 23)
# 176.1875763125763
# (91, 24)
# 127.1301282051282
# (364, 70)
# 136.30329556455462
# (281, 87)
# 143.73042109405745
# (121, 70)
# 136.70018662072926
# (324, 86)
# 117.03355119825709
# (45, 68)
# 93.1971409574468
# (47, 64)
# 97.43653645833334
# (400, 64)
# 205.99362916572633
# (633, 112)
# 212.16895683041338
# (142, 41)
# 159.05698005698005
# (96, 39)
# 149.70315091210614
# (67, 36)
# 138.5948051948052
# (44, 35)
# 204.55886994949495
# (128, 33)
# 211.91381642512079
# (69, 25)
# 214.44719576719578
# (63, 25)
# 212.89480452674897
# (54, 24)
# 210.75498188405797
# (32, 23)
# 206.58639021796915
# (57, 22)
# 208.28042614662334
# (71, 26)
# 143.277169258508
# (290, 51)
# 149.93517665130568
# (155, 49)
# 146.81277056277057
# (44, 49)
# 157.7413125129388
# (221, 51)
# 163.49078906284848
# (282, 53)
# 210.3860398860399
# (39, 18)
# 214.59473684210528
# (30, 19)
# 218.24088541666666
# (48, 16)
# 215.30208333333334
# (62, 16)
# 210.35603345280765
# (31, 18)
# 203.01721664275468
# (41, 17)
# 200.45637254901962
# (40, 17)
# 199.8880026586906
# (59, 17)
# 163.68954248366012
# (34, 12)
# 169.25907029478458
# (42, 14)
# 113.11815834104225
# (368, 47)
# 102.22737912369249
# (217, 42)
# 141.63206056812425
# (422, 53)
# 151.17800437996166
# (281, 52)
# 160.19954161294945
# (358, 52)
# 184.5570824524313
# (43, 22)
# 168.69402985074626
# (67, 20)
# 170.17363241308794
# (163, 32)
# 163.78533333333334
# (125, 30)
# 200.32035359438925
# (236, 58)
# 175.39268697759263
# (231, 53)
# 176.13135536970663
# (186, 54)
# 204.48093302361596
# (168, 41)
# 214.46493688639552
# (46, 31)
# 186.55015069318867
# (158, 35)
# 173.02336896929825
# (152, 32)
# 159.80266757865937
# (258, 34)
# 108.95871021775544
# (199, 40)
# 103.5101244101244
# (210, 37)
# 96.42612859097127
# (43, 34)
# 95.63287210655632
# (209, 37)
# 173.9873202614379
# (255, 70)
# 220.63966140053097
# (333, 92)
# 154.57597593312644
# (289, 97)
# 187.83104166666666
# (80, 120)
# 167.7391456582633
# (136, 42)
# 119.82837995337995
# (260, 44)
# 158.153608815427
# (55, 55)
# 128.08807835190814
# (329, 75)
# 89.55050741608119
# (70, 61)
# 132.9909649122807
# (304, 75)
# 127.79040550093181
# (364, 57)
# 127.27612903225807
# (155, 30)
# 103.523828125
# (160, 32)
# 143.5383122056989
# (954, 214)
# 137.7636107782012
# (946, 157)
# 145.78399537620848
# (104, 61)
# 135.3946983496164
# (396, 61)
# 229.17869834500965
# (201, 49)
# 243.38388946733437
# (243, 166)
# 220.68506132193534
# (597, 145)
# 192.3895728114478
# (528, 108)
# 127.7736765307197
# (1113, 219)
# 167.89913317572893
# (423, 106)
# 155.66319727891155
# (245, 100)
# 134.4157631680123
# (255, 85)
# 170.32936683912294
# (205, 66)
# 156.35718182526693
# (182, 47)
# 156.3787211740042
# (60, 53)
# 151.5540337770967
# (197, 53)
# 146.83319432860716
# (327, 66)
# 125.18264746227709
# (90, 54)
# 159.96371089276028
# (313, 53)
# 160.18685884950006
# (151, 51)
# 137.3107789563913
# (122, 51)
# 140.29078726968174
# (199, 55)
# 133.41838413159167
# (265, 65)
# 233.4340803709428
# (647, 200)
# 58.9844301382928
# (466, 30)
# 177.6301164924599
# (604, 83)
# 157.59570747217805
# (592, 85)
# 161.93923541247486
# (71, 35)
# 157.98418818129662
# (415, 35)
# 139.14230103806227
# (68, 34)
# 142.0544306184012
# (272, 65)
# 62.406613408838105
# (319, 31)
# 72.07430759889776
# (183, 39)
# 72.0020325203252
# (188, 41)
# 72.28832070707071
# (132, 40)
# 69.39526810998447
# (178, 41)
# 153.39085561125034
# (684, 84)
# 152.4080537670846
# (454, 78)
# 153.9517543859649
# (32, 38)
# 149.71338652482268
# (188, 40)
# 139.65062761506277
# (239, 38)
# 149.72975007527853
# (164, 27)
# 152.6982234689107
# (46, 93)
# 86.93433566433566
# (286, 50)
# 157.5374301038457
# (127, 46)
# 156.13600403124212
# (294, 45)
# 135.87233653406494
# (81, 45)
# 150.34790872560868
# (529, 61)
# 144.55519168369187
# (628, 53)
# 145.76408787010507
# (349, 79)
# 185.8462721793737
# (719, 110)
# 179.4115579710145
# (115, 80)
# 167.8768685018685
# (858, 84)
# 93.06186666666666
# (25, 25)
# 114.17661913250149
# (44, 51)
# 106.61873638344227
# (17, 54)
# 100.55756704980843
# (174, 20)
# 98.06970894717931
# (121, 23)
# 96.73028673835125
# (93, 24)
# 92.18592592592593
# (75, 24)
# 125.62992606878817
# (366, 85)
# 112.05830654625235
# (556, 94)
# 202.18868317037652
# (418, 92)
# 158.22137095518391
# (139, 77)
# 165.67827473042664
# (450, 79)
# 149.85485688528286
# (102, 29)
# 137.33703703703705
# (33, 30)
# 128.41361111111112
# (48, 25)
# 96.17138364779875
# (53, 28)
# 111.51144811180494
# (59, 19)
# 120.62358276643991
# (77, 21)
# 123.43181818181819
# (33, 20)
# 114.08049886621315
# (49, 24)
# 116.78142361111111
# (80, 24)
# 133.15954415954417
# (63, 13)
# 108.32766439909297
# (42, 14)
# 99.39462702138758
# (71, 18)
# 97.48538011695906
# (57, 19)
# 100.58666666666667
# (15, 15)
# 83.74551971326164
# (62, 18)
# 78.72543859649123
# (76, 15)
# 94.68499511241447
# (62, 22)
# 104.88253968253969
# (28, 15)
# 96.02358276643992
# (49, 15)
# 100.47683397683397
# (37, 14)
# 93.21777777777778
# (15, 15)
# 83.99166666666666
# (40, 13)
# 76.05029239766081
# (76, 15)
# 74.18187134502924
# (76, 15)
# 91.60732714138287
# (34, 19)
# 97.85006435006434
# (74, 14)
# 90.96918767507003
# (17, 14)
# 75.19318181818181
# (32, 22)
# 65.62468671679198
# (112, 19)
# 59.79824561403509
# (19, 16)
# 53.30482456140351
# (112, 19)
# 186.01193633952255
# (319, 78)
# 161.93014705882354
# (324, 68)
# 163.5960054055292
# (539, 81)
# 136.82771164021165
# (168, 36)
# 157.3868881118881
# (143, 40)
# 131.7951038403527
# (169, 34)
# 149.74291666666667
# (96, 25)
# 160.99721706864565
# (49, 22)
# 156.66682170542634
# (86, 25)
# 148.59698025551685
# (41, 28)
# 151.75550854926846
# (61, 31)
# 196.89907737589857
# (302, 39)
# 153.69699766211394
# (301, 36)
# 185.5217050018255
# (220, 83)
# 199.38396624472574
# (122, 79)
# 197.1728943448375
# (453, 82)
# 171.3544520547945
# (292, 86)
# 182.8511293025463
# (494, 91)
# 188.57937108566622
# (855, 357)
# 210.13383711167086
# (397, 115)
# 204.22574595055414
# (323, 115)
# 207.16321974148062
# (222, 115)
# 185.1302469590557
# (617, 264)
# 94.63180780447892
# (377, 134)
# 99.77062987077045
# (248, 109)
# 98.45716673210708
# (293, 113)
# 128.0021287661623
# (762, 217)
# 162.33477797413673
# (699, 136)
# 161.07777777777778
# (60, 28)
# 82.88166406950937
# (181, 39)
# 66.08103405418842
# (149, 36)
# 55.59176441837732
# (88, 31)
# 190.96106765306328
# (1195, 276)
# 83.00860117700317
# (188, 47)
# 116.11892712550608
# (52, 38)
# 113.52197368421052
# (190, 40)
# 124.29169308814204
# (83, 38)
# 116.83216747769667
# (137, 48)
# 96.4951923076923
# (26, 32)
# 100.82271634615384
# (64, 26)
# 92.5
# (56, 27)
# 100.2649748513946
# (54, 27)
# 98.41739980449658
# (31, 22)
# 91.34408602150538
# (90, 31)
# 79.95707070707071
# (84, 33)
# 77.52253804191788
# (43, 27)
# 85.125
# (40, 26)
# 65.07748883635408
# (47, 27)
# 52.5167297979798
# (66, 32)
# 94.15614261168385
# (97, 32)
# 195.4623708010336
# (258, 56)
# 179.61754029777285
# (172, 63)
# 79.15084780810588
# (104, 31)
# 201.98156144530475
# (438, 92)
# 159.38717618434234
# (137, 85)
# 140.84932054356514
# (417, 86)
# 161.20454962392222
# (79, 23)
# 167.66282543747332
# (71, 22)
# 167.46119196119196
# (37, 26)
# 171.59530864197532
# (54, 25)
# 189.47863247863248
# (48, 26)
# 214.8904347826087
# (25, 23)
# 170.02160280276323
# (453, 134)
# 147.06707509881423
# (253, 100)
# 182.73712333692916
# (450, 103)
# 156.89370218579236
# (244, 100)
# 134.64767331433998
# (219, 117)
# 124.2031746031746
# (35, 24)
# 165.8179033202685
# (151, 49)
# 171.62579453067258
# (110, 41)
# 164.00092284976006
# (43, 42)
# 160.75319411401887
# (97, 39)
# 155.39572516441675
# (107, 36)
# 143.44752252252252
# (120, 37)
# 137.98098765432098
# (75, 36)
# 131.74165594165595
# (111, 35)
# 82.30417777777778
# (75, 25)
# 79.95726495726495
# (36, 26)
# 79.87948717948719
# (55, 26)
# 80.88717948717948
# (39, 25)
# 81.07431614621157
# (51, 27)
# 80.4748062015504
# (86, 26)
# 81.8452380952381
# (58, 28)
# 80.41704374057315
# (51, 26)
# 82.67048794826573
# (42, 27)
# 83.20096890139084
# (79, 27)
# 71.51966865526188
# (429, 59)
# 81.69929245283019
# (318, 56)
# 64.4540903036149
# (246, 59)
# 115.58488612836439
# (161, 40)
# 101.0400703871292
# (170, 39)
# 102.95841200677802
# (153, 45)
# 97.20494516863232
# (179, 36)
# 99.76718336938237
# (146, 38)
# 107.57790021426385
# (121, 36)
# 90.28817204301075
# (93, 35)
# 100.46851085370574
# (473, 71)
# 118.273033126294
# (161, 24)
# 140.5937182571505
# (290, 43)
# 136.6592261904762
# (168, 44)
# 118.91136363636363
# (176, 25)
# 124.37388663967612
# (190, 26)
# 149.82229104104104
# (333, 64)
# 127.91378958120531
# (178, 55)
# 125.53670675300647
# (575, 282)
# 112.62250476795931
# (605, 117)
# 104.49037981822521
# (847, 127)
# 110.89884173602546
# (891, 101)
# 123.64671171171172
# (300, 74)
# 124.43667554919196
# (289, 87)
# 141.3169398907104
# (244, 72)
# 133.20192903766912
# (277, 66)
# 135.89340894148586
# (78, 52)
# 130.62122869382918
# (138, 53)
# 116.95963270963271
# (296, 52)
# 118.81083381379898
# (213, 57)
# 130.69403594771242
# (272, 60)
# 129.7919167667067
# (85, 49)
# 126.38172715894869
# (306, 47)
# 126.77453673777204
# (119, 104)
# 110.54922983731394
# (360, 107)
# 102.58921041534893
# (124, 102)
# 63.512188659247485
# (74, 17)
# 122.01227541569021
# (103, 29)
# 133.5660697327364
# (117, 42)
# 123.94768194768194
# (99, 39)
# 100.15212728814404
# (163, 41)
# 111.56125226860254
# (152, 29)
# 113.85748792270532
# (138, 41)
# 153.00311168868674
# (513, 90)
# 112.24918981481481
# (120, 48)
# 139.9954410379068
# (511, 90)
# 123.71172374490214
# (367, 51)
# 121.12824242424243
# (275, 100)
# 104.50129779375062
# (126, 106)
# 154.55911517925247
# (19, 23)
# 90.52985436893204
# (103, 40)
# 106.9729545930111
# (432, 118)
# 94.915625
# (20, 32)
# 117.77374551971326
# (120, 31)
# 97.84231200897868
# (18, 33)
# 103.63425370148059
# (147, 34)
# 104.19775132275132
# (90, 28)
# 109.89780842157104
# (131, 31)
# 112.2374823545419
# (564, 139)
# 101.37771232204221
# (97, 35)
# 90.44107744107744
# (84, 33)
# 95.70618502572718
# (267, 107)
# 131.29345104416737
# (349, 37)
# 115.60298529852986
# (303, 88)
# 115.16242424242424
# (55, 15)
# 68.09302451358185
# (277, 89)
# 96.54556387442129
# (576, 192)
# 52.22292002147075
# (135, 92)
# 92.9862258953168
# (165, 33)
# 96.33582366343454
# (233, 54)
# 100.33496434531938
# (169, 52)
# 169.60902105078722
# (193, 69)
# 150.9599895670318
# (360, 71)
# 108.43653576437588
# (138, 62)
# 111.48305950060336
# (133, 54)
# 106.87934135879341
# (219, 55)
# 102.46575163398693
# (102, 50)
# 171.88377104377105
# (396, 75)
# 106.01588514769675
# (515, 94)
# 109.14045301966094
# (585, 101)
# 158.1505376344086
# (26, 31)
# 140.56700604987458
# (502, 90)
# 150.14105090311986
# (70, 29)
# 145.82976040353088
# (61, 26)
# 179.06328847771238
# (232, 41)
# 182.01153846153846
# (104, 35)
# 155.95417242008182
# (293, 131)
# 181.0762670565302
# (144, 38)
# 164.89290998402083
# (554, 61)
# 128.6558399008235
# (491, 115)
# 118.70432992299419
# (389, 149)
# 145.42260382413835
# (476, 184)
# 130.40040461432505
# (605, 128)
# 120.67686153052007
# (123, 42)
# 124.45848608457686
# (362, 107)
# 128.4561371288644
# (121, 45)
# 133.64516375880012
# (99, 44)
# 120.22932330827068
# (266, 29)
# 168.0897655151446
# (179, 49)
# 170.5430894308943
# (41, 25)
# 153.28903903903904
# (74, 24)
# 78.74931196373645
# (142, 29)
# 124.63015873015873
# (147, 30)
# 196.76916010498687
# (254, 50)
# 134.31823745410037
# (43, 19)
# 129.143115942029
# (32, 23)
# 155.20104895104896
# (22, 26)
# 148.5051440329218
# (24, 27)
# 133.10675381263616
# (27, 17)
# 134.92118537200506
# (61, 26)
# 126.29692760942761
# (132, 36)
# 128.12353088272067
# (172, 31)
# 122.13981481481481
# (75, 24)
# 124.58198757763975
# (70, 23)
# 142.6192876344086
# (128, 31)
# 137.63548310890621
# (83, 17)
# 128.6757671957672
# (63, 25)
# 126.44160798122066
# (71, 32)
# 119.85181079083519
# (82, 22)
# 148.890544375645
# (152, 34)
# 124.80335097001763
# (18, 21)
# 150.24775533108865
# (44, 27)
# 143.91423423423424
# (37, 25)
# 142.01362625139043
# (116, 31)
# 134.25850815850816
# (65, 22)
# 120.32618357487922
# (75, 23)
# 135.6438172043011
# (62, 32)
# 129.3029761904762
# (28, 20)
# 145.37827380952382
# (35, 32)
# 149.03174376546735
# (206, 34)
# 134.66694214876034
# (55, 22)
# 172.55250506072875
# (208, 38)
# 168.76653672032194
# (284, 56)
# 118.04549163606691
# (172, 57)
# 125.73024817850637
# (288, 61)
# 114.84506599622878
# (74, 43)
# 146.0979432708756
# (294, 57)
# 159.4250108932462
# (255, 60)
# 125.32934556336195
# (305, 168)
# 104.72539682539683
# (14, 15)
# 102.93968253968254
# (14, 15)
# 120.25909630560794
# (258, 37)
# 119.52092165898617
# (155, 35)
# 119.3287197231834
# (17, 17)
# 101.62120886632165
# (539, 95)
# 102.84556382129198
# (206, 77)
# 105.5813492063492
# (84, 36)
# 113.71432842195173
# (223, 35)
# 128.463699339988
# (291, 105)
# 100.97485525227461
# (260, 62)
# 165.51274715493673
# (294, 107)
# 145.02057557826788
# (143, 52)
# 132.91048557353977
# (145, 49)
# 132.76590436590436
# (296, 65)
# 134.36128033302873
# (196, 67)
# 126.16110082685425
# (370, 73)
# 123.52847563958674
# (351, 66)
# 110.225
# (200, 62)
# 108.7763751979765
# (239, 59)
# 116.58127219112957
# (191, 58)
# 150.18037452356978
# (507, 143)
# 187.5852295852296
# (273, 99)
# 101.04204941860465
# (430, 160)
# 99.44571911431927
# (431, 108)
# 93.86284707540521
# (430, 110)
# 165.6205400192864
# (136, 61)
# 103.71878118044363
# (86, 101)
# 157.35644339992166
# (148, 46)
# 154.0770815368401
# (142, 49)
# 144.144314019314
# (154, 52)
# 125.46470797720798
# (156, 60)
# 151.41252955082743
# (216, 94)
# 138.0438730324117
# (349, 77)
# 160.56166835528538
# (282, 35)
# 161.00674068199842
# (194, 39)
# 156.78663375919473
# (164, 42)
# 109.6610835837155
# (933, 244)
# 104.53165424233833
# (983, 244)
# 89.6190180370017
# (786, 256)
# 82.69029590799556
# (564, 207)
# 179.36368082368082
# (259, 50)
# 172.86783968719453
# (220, 31)
# 172.53623413623413
# (195, 33)
# 179.13097398669086
# (152, 29)
# 86.89374514374515
# (66, 26)
# 96.3131632581348
# (153, 31)
# 88.30451900034235
# (381, 46)
# 85.28571175480556
# (355, 53)
# 95.5685534591195
# (106, 50)
# 95.20338753387534
# (82, 30)
# 76.54444165200637
# (173, 46)
# 94.69012204424104
# (38, 46)
# 83.94581309275966
# (131, 44)
# 84.81298701298701
# (77, 45)
# 92.2543009071004
# (139, 46)
# 91.0698717948718
# (104, 45)
# 95.76628352490421
# (87, 31)
# 194.86520241171405
# (43, 18)
# 137.92173423423424
# (37, 16)
# 124.86974789915966
# (68, 21)
# 139.31005291005292
# (42, 15)
# 136.01388888888889
# (52, 18)
# 124.7421052631579
# (57, 20)
# 132.95324074074074
# (40, 18)
# 127.55104166666666
# (16, 20)
# 130.29437456324249
# (106, 18)
# 179.46352583586625
# (47, 42)
# 134.53918231041078
# (149, 69)
# 153.28937853107345
# (200, 59)
# 136.88920403920403
# (455, 148)
# 135.1220238095238
# (316, 56)
# 128.24404761904762
# (179, 56)
# 124.2017862952119
# (221, 51)
# 124.64820213799806
# (98, 49)
# 134.74907142099119
# (349, 72)
# 132.20920949237782
# (202, 105)
# 126.66369197251551
# (156, 51)
# 98.60860484544695
# (38, 21)
# 91.02068376068377
# (78, 25)
# 111.6868961352657
# (92, 24)
# 86.65270935960591
# (87, 28)
# 90.69638888888889
# (180, 20)
# 87.25613275613276
# (66, 21)
# 84.8870497833133
# (339, 54)
# 87.5767575322812
# (41, 17)
# 89.80741626794259
# (44, 19)
# 135.4151138716356
# (56, 69)
# 136.89985422740526
# (147, 140)
# 140.28489042675895
# (17, 17)
# 93.17791005291005
# (21, 24)
# 104.47272727272727
# (25, 22)
# 107.00927492636461
# (197, 27)
# 125.63484116272657
# (446, 103)
# 76.06354166666667
# (16, 20)
# 93.2149143933091
# (557, 123)
# 93.83350770124963
# (310, 74)
# 62.05104166666667
# (16, 20)
# 158.29820415879016
# (92, 46)
# 145.16006734006734
# (110, 45)
# 137.57234397026784
# (204, 51)
# 146.95437844458053
# (142, 46)
# 102.02516191007406
# (347, 62)
# 100.9805754874248
# (378, 73)
# 103.78036484245439
# (150, 67)
# 104.77855879752431
# (232, 65)
# 98.09262701363073
# (269, 72)
# 146.72716915785637
# (422, 52)
# 122.69767441860465
# (86, 69)
# 121.13026358084217
# (61, 68)
# 148.00997592019263
# (133, 51)
# 207.28240740740742
# (60, 60)
# 122.47018204645323
# (59, 27)
# 124.5389363722697
# (26, 27)
# 132.52929292929292
# (110, 27)
# 134.71022263071896
# (204, 32)
# 130.5387578237843
# (134, 31)
# 118.17775974025975
# (44, 28)
# 130.52975217864923
# (153, 32)
# 131.77859477124184
# (136, 33)
# 81.45481481481481
# (60, 15)
# 138.18830749354007
# (129, 32)
# 85.18341924398625
# (97, 16)
# 127.38980392156863
# (85, 25)
# 81.4470310391363
# (52, 19)
# 130.94980158730158
# (168, 30)
# 107.7719298245614
# (146, 38)
# 91.44951171875
# (256, 40)
# 88.81550387596899
# (165, 43)
# 94.7495175848117
# (153, 35)
# 109.15986227250369
# (107, 38)
# 147.9434579261569
# (289, 91)
# 170.48528433654806
# (194, 62)
# 142.2288994236847
# (163, 88)
# 154.1696379843551
# (239, 46)
# 147.7600121129533
# (238, 37)
# 162.17972126033825
# (421, 83)
# 172.00825673278504
# (159, 65)
# 168.90777777777777
# (130, 60)
# 97.12976816676408
# (295, 58)
# 174.19867149758454
# (48, 46)
# 172.0848588863463
# (38, 46)
# 160.44719926538107
# (33, 44)
# 91.34932635456043
# (181, 76)
# 121.87210683157447
# (261, 57)
# 124.95270072381909
# (257, 62)
# 127.55021298567188
# (254, 61)
# 52.91641641641642
# (90, 37)
# 75.17696848201359
# (292, 41)
# 42.65367316341829
# (29, 23)
# 127.47821350762527
# (17, 18)
# 69.64144144144144
# (37, 25)
# 131.13713487490335
# (581, 115)
# 150.49670439000124
# (561, 172)
# 149.57018066642604
# (549, 217)
# 71.06101241642789
# (349, 75)
# 79.46330569375345
# (201, 75)
# 143.4860674570352
# (465, 78)
# 68.07711450428584
# (538, 121)
# 190.35158862566269
# (405, 111)
# 199.04130329457365
# (224, 86)
# 138.53561320754716
# (106, 40)
# 130.66022198353025
# (196, 38)
# 136.09302536231883
# (92, 40)
# 133.5915650406504
# (80, 41)
# 140.57355112587672
# (129, 28)
# 144.3599498635995
# (137, 33)
# 136.740832416575
# (202, 54)
# 129.3754426260886
# (258, 54)
# 148.15239726027397
# (146, 44)
# 138.26421845574387
# (295, 54)
# 151.3856450685719
# (99, 41)
# 92.5228735632184
# (116, 25)
# 97.16987654320988
# (81, 25)
# 89.57689305230289
# (61, 21)
# 91.38511659807956
# (72, 27)
# 126.71711259754738
# (161, 52)
# 128.21473660689347
# (117, 51)
# 103.58196611978124
# (49, 51)
# 44.857347670250896
# (93, 20)
# 135.1699117832388
# (230, 46)
# 42.50592592592593
# (90, 20)
# 139.03186602870812
# (209, 50)
# 39.827894736842104
# (95, 20)
# 123.1908663983132
# (188, 37)
# 173.2723757266967
# (315, 81)
# 144.22701149425288
# (145, 64)
# 140.67097609001405
# (375, 79)
# 147.90191570881225
# (285, 87)
# 84.53740740740741
# (100, 27)
# 140.8369845165591
# (193, 57)
# 77.70317760942761
# (297, 32)
# 127.49117647058823
# (85, 40)
# 96.9971777253754
# (473, 208)
# 110.1484456343894
# (83, 27)
# 92.39908125179443
# (43, 27)
# 128.28451178451178
# (33, 24)
# 184.7085769980507
# (114, 24)
# 182.31330543377175
# (193, 52)
# 171.46113821138212
# (123, 25)
# 185.3387545787546
# (91, 25)
# 208.4022988505747
# (117, 29)
# 188.99757655871338
# (267, 51)
# 130.41401515151514
# (154, 40)
# 121.58221654232293
# (517, 56)
# 130.58681608437706
# (185, 41)
# 75.28086055358783
# (121, 21)
# 127.02391757955138
# (355, 36)
# 69.33482384823849
# (123, 20)
# 75.09411421911422
# (52, 22)
# 77.00721682286243
# (536, 86)
# 100.16636890260408
# (131, 47)
# 91.29688902567258
# (317, 41)
# 115.83099906629319
# (21, 17)
# 84.30067567567568
# (111, 32)
# 104.88621022179363
# (61, 17)
# 86.84789813361242
# (196, 39)
# 88.45072912063632
# (73, 31)
# 88.15139826422372
# (61, 17)
# 99.3069074453552
# (256, 61)
# 109.6044061302682
# (58, 18)
# 109.97083333333333
# (16, 15)
# 85.48504629629629
# (200, 36)
# 107.16348039215686
# (80, 17)
# 111.6017094017094
# (26, 15)
# 101.80998389694042
# (23, 18)
# 104.62091503267973
# (15, 17)
# 93.80661231884058
# (46, 16)
# 88.12127880677303
# (399, 82)
# 88.8308300395257
# (115, 33)
# 172.88947368421051
# (19, 20)
# 167.63398692810458
# (17, 21)
# 191.35939434875604
# (141, 42)
# 155.20313230481534
# (46, 31)
# 181.81182795698925
# (60, 31)
# 191.6184681460272
# (127, 33)
# 180.12082625919638
# (76, 31)
# 159.11373456790125
# (72, 30)
# 175.73202614379085
# (42, 34)
# 178.68536428110897
# (47, 33)
# 179.06696428571428
# (28, 32)
# 175.70515873015873
# (30, 28)
# 181.8559829059829
# (26, 30)
# 179.33470695970695
# (26, 28)
# 178.72222222222223
# (63, 26)
# 167.4907268170426
# (95, 28)
# 179.91728670634922
# (96, 28)
# 186.73607038123168
# (33, 31)
# 188.92510893246188
# (36, 34)
# 171.97918050941306
# (43, 35)
# 176.43313492063493
# (56, 30)
# 189.03929146537843
# (69, 30)
# 148.4187885802469
# (54, 32)
# 77.59413798522709
# (202, 42)
# 97.79735779015176
# (142, 43)
# 95.83155236576289
# (285, 44)
# 91.48488017429194
# (150, 51)
# 96.17910234419668
# (159, 44)
# 78.14818862578426
# (183, 45)
# 129.43204386930984
# (454, 160)
# 92.84019343229869
# (247, 48)
# 126.22348484848484
# (154, 36)
# 137.24652519235542
# (158, 34)
# 101.54755555555556
# (150, 20)
# 105.45852169981917
# (158, 56)
# 106.69534313725491
# (136, 20)
# 104.79726645435244
# (314, 80)
# 111.73306233062331
# (41, 42)
# 107.18308702791461
# (84, 29)
# 206.1214990138067
# (65, 65)
# 202.22501482799527
# (281, 32)
# 172.4995593160585
# (122, 31)
# 161.26581831035702
# (69, 82)
# 181.18877192982455
# (125, 38)
# 198.19109865064155
# (219, 386)
# 158.55733619973617
# (211, 388)
# 205.06175264030725
# (201, 38)
# 186.9687299207539
# (203, 46)
# 180.51731078904993
# (46, 36)
# 181.6201550387597
# (219, 43)
# 104.9324118804795
# (207, 36)
# 97.11722552731206
# (172, 43)
# 109.64485737571312
# (409, 100)
# 138.80369722869722
# (180, 286)
# 112.16277480191943
# (412, 58)
# 86.33098039215686
# (17, 25)
# 86.01566272154507
# (153, 37)
# 93.6824693546005
# (61, 37)
# 73.63711367207962
# (166, 46)
# 112.16601849451214
# (133, 29)
# 161.07927623785832
# (134, 84)
# 173.91953664744688
# (414, 93)
# 208.375
# (44, 40)
# 123.53752406222361
# (596, 129)
# 206.809509775027
# (87, 39)
# 218.5901467505241
# (53, 24)
# 108.17350427350428
# (65, 24)
# 119.37384615384616
# (50, 26)
# 105.28181565023671
# (57, 21)
# 82.06062801932367
# (60, 23)
# 79.71087962962963
# (60, 24)
# 112.59144237405107
# (63, 23)
# 109.30764643519746
# (196, 77)
# 109.3402280793623
# (337, 34)
# 102.21207133058985
# (135, 36)
# 114.02928571428572
# (50, 28)
# 146.00717948717949
# (65, 30)
# 216.0572567114094
# (298, 64)
# 104.89736381809095
# (116, 46)
# 111.7391431069659
# (146, 47)
# 125.76695491379779
# (227, 108)
# 151.35897435897436
# (26, 26)
# 226.66238347190728
# (63, 42)
# 229.44670893719805
# (48, 46)
# 193.384599418846
# (73, 22)
# 111.04531607006855
# (101, 26)
# 117.68888888888888
# (30, 27)
# 125.3051776266062
# (63, 28)
# 124.85038314176245
# (60, 29)
# 122.85686274509804
# (85, 26)
# 208.47025160606935
# (197, 246)
# 105.38031452505136
# (222, 38)
# 198.04528855363984
# (192, 58)
# 88.90260768698833
# (293, 51)
# 136.14605597964376
# (131, 65)
# 128.9041676251821
# (189, 92)
# 124.50674575154169
# (365, 97)
# 104.40965982028241
# (328, 95)
# 90.1853676336435
# (105, 87)
# 125.25752314814815
# (24, 24)
# 107.5789221327196
# (158, 88)
# 105.18300302145747
# (283, 92)
# 112.56061756212371
# (557, 149)
# 91.74033041117323
# (439, 66)
# 119.5890197584603
# (292, 107)
# 116.25539265251095
# (92, 43)
# 118.26181533646323
# (142, 45)
# 111.43849226078022
# (452, 89)
# 109.82853223593965
# (27, 27)
# 118.59991408934708
# (194, 40)
# 123.5369728957062
# (129, 47)
# 119.72258953168044
# (121, 30)
# 124.4007561436673
# (46, 46)
# 128.35878787878787
# (100, 44)
# 118.11985624438455
# (212, 35)
# 134.0149528410398
# (69, 42)
# 117.26992967651195
# (237, 50)
# 126.78204953419677
# (163, 45)
# 119.55797701149426
# (125, 29)
# 116.76714931782769
# (179, 49)
# 134.2716586151369
# (92, 45)
# 134.28730158730158
# (50, 42)
# 130.04738423969192
# (338, 42)
# 129.34847272242231
# (119, 42)
# 122.89240842490842
# (364, 100)
# 142.69103313840156
# (323, 36)
# 141.7037037037037
# (165, 42)
# 133.09326974032857
# (119, 37)
# 111.88317962231005
# (99, 46)
# 109.66285367334548
# (305, 45)
# 118.68533799533799
# (260, 55)
# 108.51086018411968
# (316, 44)
# 113.03835978835978
# (63, 44)
# 137.61091351132322
# (501, 133)
# 159.4126984126984
# (42, 17)
# 162.78742310321257
# (77, 19)
# 159.760348583878
# (63, 17)
# 169.30940988835727
# (22, 19)
# 158.04984126984127
# (70, 15)
# 174.97409579667644
# (31, 22)
# 131.0828651874604
# (454, 109)
# 175.69583333333333
# (76, 20)
# 172.44654335563428
# (121, 21)
# 154.61618217054263
# (160, 86)
# 154.82602089268755
# (270, 91)
# 156.41590170135947
# (461, 151)
# 142.43115654836967
# (610, 182)
# 79.63362787272797
# (564, 122)
# 112.08362208362209
# (37, 39)
# 92.84386764002413
# (517, 62)
# 114.34680879592383
# (113, 44)
# 122.90348484848485
# (50, 44)
# 121.97323671497584
# (69, 50)
# 112.49019607843137
# (68, 40)
# 168.13704719869577
# (505, 83)
# 107.56440432152007
# (561, 93)
# 89.5349496033876
# (414, 108)
# 71.70392881454828
# (364, 113)
# 98.39063545150502
# (325, 115)
# 60.92539848228783
# (479, 84)
# 91.3576231060606
# (240, 88)
# 106.69770452922883
# (489, 169)
# 86.39166161616161
# (550, 120)
# 80.61969051718063
# (586, 113)
# 117.2406780240832
# (336, 116)
# 117.01826454197143
# (319, 96)
# 106.1460075858332
# (505, 134)
# 176.3442585349365
# (236, 117)
# 160.6054538606403
# (295, 150)
# 185.67541389315582
# (217, 72)
# 155.45494252873564
# (174, 50)
# 140.24742455184932
# (113, 65)
# 151.36907807000284
# (193, 79)
# 152.7335063811378
# (67, 69)
# 142.57893217893218
# (77, 60)
# 85.62755716004814
# (554, 63)
# 133.7282591072112
# (499, 103)
# 120.90503597122301
# (139, 45)
# 140.6985236985237
# (195, 44)
# 139.197801789759
# (191, 47)
# 138.72138622891018
# (129, 51)
# 125.54327791269694
# (202, 53)
# 157.47536518199234
# (232, 48)
# 110.09219744798743
# (582, 129)
# 98.72215620254836
# (594, 136)
# 131.53389663427686
# (263, 45)
# 136.38392769427253
# (261, 39)
# 133.20398671096345
# (70, 43)
# 125.85929473830349
# (98, 49)
# 120.08099906629319
# (238, 48)
# 72.66954022988506
# (609, 76)
# 89.24576827152461
# (580, 212)
# 141.84
# (325, 172)
# 91.13333333333334
# (95, 14)
# 141.81230936819173
# (170, 18)
# 126.22156215621563
# (101, 15)
# 88.2408148226129
# (354, 161)
# 86.43749407414431
# (424, 199)
# 97.65499921365102
# (471, 144)
# 75.01585996240601
# (336, 152)
# 116.36132598322516
# (489, 92)
# 147.3149387820247
# (487, 223)
# 142.05748512333238
# (604, 92)
# 170.30187411425499
# (359, 76)
# 118.02528837622005
# (196, 46)
# 118.57668989744461
# (333, 53)
# 116.97171160130719
# (192, 51)
# 110.93345238095237
# (175, 48)
# 99.48347601951579
# (568, 102)
# 108.49983490805649
# (579, 136)
# 109.1214427302089
# (346, 139)
# 94.39347237414022
# (569, 143)
# 64.96253968253968
# (105, 20)
# 52.867753623188406
# (138, 20)
# 81.02616858237548
# (435, 60)
# 93.51428571428572
# (357, 25)
# 140.20623426239473
# (349, 55)
# 200.5140492582353
# (429, 43)
# 143.08760546642898
# (510, 110)
# 105.5276545400769
# (98, 46)
# 121.00376178031203
# (183, 46)
# 137.5501711156742
# (487, 50)
# 113.47707275331585
# (594, 181)
# 110.02477710327032
# (317, 119)
# 120.310322156476
# (338, 69)
# 94.26957151056874
# (361, 74)
# 106.2644281468699
# (183, 76)
# 145.01771744132535
# (164, 53)
# 137.72515964240102
# (145, 63)
# 141.31305260831124
# (116, 52)
# 134.87916666666666
# (50, 40)
# 135.6278801843318
# (62, 42)
# 131.12301587301587
# (28, 30)
# 135.03302752293578
# (109, 40)
# 143.2051204209674
# (108, 61)
# 149.33169129720855
# (29, 35)
# 143.3762989285522
# (151, 41)
# 132.40662650602408
# (83, 36)
# 131.49577417173765
# (58, 34)
# 136.8504490923937
# (87, 61)
# 135.6085390946502
# (27, 24)
# 142.99106836138785
# (142, 41)
# 145.0999436936937
# (32, 37)
# 149.52964285714285
# (70, 40)
# 138.5367088607595
# (79, 45)
# 130.7251828631139
# (22, 29)
# 135.68412698412698
# (112, 45)
# 137.73963133640552
# (31, 28)
# 139.45319865319865
# (90, 55)
# 141.4163773148148
# (64, 36)
# 145.50208489254786
# (199, 47)
# 137.3297619047619
# (135, 56)
# 135.4696342305038
# (69, 42)
# 136.27090643274855
# (120, 38)
# 145.53664205633032
# (53, 46)
# 109.63298411625549
# (269, 44)
# 71.2822947095099
# (316, 39)
# 137.9017094017094
# (63, 26)
# 147.0185185185185
# (64, 27)
# 132.33552271483305
# (84, 29)
# 111.2874503885069
# (445, 134)
# 109.23043613707165
# (200, 107)
# 111.50188544003989
# (191, 112)
# 100.61726493653488
# (620, 133)
# 104.28647251903065
# (222, 86)
# 105.32545857052499
# (310, 68)
# 179.592693579742
# (243, 163)
# 75.92093661212893
# (708, 346)
# 158.54603174603176
# (273, 75)
# 107.07346415489273
# (637, 100)
# 150.9956043956044
# (35, 13)
# 170.96614492753622
# (115, 25)
# 165.24504414459437
# (87, 23)
# 141.28644982298474
# (512, 153)
# 178.89446132057367
# (489, 103)
# 156.40090250564066
# (401, 112)
# 135.8839527680991
# (420, 123)
# 85.829307568438
# (115, 18)
# 49.284074605451934
# (41, 17)
# 98.23338115734099
# (41, 17)
# 116.39436030537254
# (377, 93)
# 145.91130037390943
# (174, 83)
# 82.75345597274041
# (521, 89)
# 109.84644279167605
# (261, 51)
# 114.39960943727084
# (164, 51)
# 111.86228070175439
# (114, 40)
# 100.99565160955348
# (214, 48)
# 114.40989736448502
# (281, 46)
# 113.53106011284723
# (256, 48)
# 106.50959731661486
# (333, 57)
# 96.47486055099739
# (423, 102)
# 107.17889509621354
# (537, 80)
# 47.677700348432055
# (42, 41)
# 48.82775919732441
# (26, 23)
# 52.930265654648956
# (62, 34)
# 100.99596678529063
# (281, 60)
# 85.92512413108243
# (95, 53)
# 97.91942752438965
# (127, 53)
# 104.69992557150452
# (275, 57)
# 123.17430851423548
# (186, 53)
# 140.36495787350185
# (106, 53)
# 126.44226334137838
# (113, 55)
# 83.83820512820513
# (26, 50)
# 169.155
# (40, 20)
# 175.57070707070707
# (66, 18)
# 135.63789682539684
# (56, 30)
# 133.2401157184185
# (122, 34)
# 141.01353686635946
# (112, 31)
# 80.6811679404272
# (81, 21)
# 79.17403767403768
# (111, 22)
# 155.900548696845
# (27, 18)
# 180.9929718875502
# (83, 24)
# 166.87174833635814
# (29, 19)
# 160.74970760233919
# (45, 19)
# 177.71929824561403
# (38, 24)
# 116.64965175259293
# (259, 68)
# 114.94231842461932
# (226, 37)
# 124.15455290262172
# (178, 32)
# 116.97131825703254
# (259, 42)
# 202.1011574074074
# (45, 32)
# 75.63019250253292
# (112, 47)
# 195.34273504273503
# (39, 20)
# 97.79700431232223
# (692, 105)
# 132.75595238095238
# (56, 10)
# 162.89800323799244
# (109, 85)
# 109.06633952678789
# (1117, 293)
# 135.9535533362281
# (470, 98)
# 120.26812313803376
# (57, 53)
# 168.64468533574225
# (41, 54)
# 44.37269176136363
# (352, 96)
# 188.1368016793092
# (274, 51)
# 175.04551886792453
# (400, 106)
# 84.68147828587863
# (38, 61)
# 39.842814286522895
# (234, 151)
# 93.28080001982701
# (257, 157)
# 84.96561014529269
# (567, 175)
# 156.248782161235
# (265, 55)
# 154.01921296296297
# (270, 112)
# 174.02448173926058
# (272, 131)
# 160.60761711024466
# (347, 153)
# 169.56282670630497
# (345, 78)
# 167.01114447781114
# (333, 105)
# 151.29858104858104
# (88, 63)
# 54.83130812002684
# (228, 122)
# 51.85360945360945
# (259, 55)
# 76.22995412547651
# (67, 77)
# 41.82129717540945
# (383, 88)
# 53.68860392506691
# (380, 118)
# 104.61646994980329
# (351, 84)
# 114.05202714850773
# (206, 72)
# 110.25735143402235
# (243, 87)
# 95.80803571428571
# (308, 88)
# 196.3699864498645
# (120, 41)
# 207.52324487107097
# (161, 44)
# 186.72165404040405
# (120, 44)
# 163.22435982780812
# (406, 74)
# 124.20021895397835
# (728, 133)
# 170.80066445182723
# (258, 63)
# 176.5066384180791
# (120, 59)
# 147.24739393755561
# (634, 208)
# 57.5581975071908
# (149, 70)
# 113.01735427630257
# (341, 73)
# 77.97663244260103
# (382, 77)
# 58.26842336407554
# (110, 69)
# 77.48021308980213
# (216, 73)
# 76.08287303639284
# (254, 67)
# 112.85029761904762
# (56, 40)
# 136.84415152658724
# (458, 81)
# 109.46130874480791
# (923, 327)
# 137.77036368015413
# (880, 346)
# 144.70710227272727
# (320, 66)
# 147.1777885235332
# (94, 66)
# 122.84997821350763
# (612, 75)
# 203.52388349339708
# (733, 101)
# 169.95451167728237
# (157, 80)
# 201.65817225410248
# (301, 88)
# 157.86729545101693
# (339, 76)
# 171.43118647429222
# (415, 81)
# 142.7319568218903
# (257, 62)
# 135.61617556783304
# (362, 78)
# 152.77858946608947
# (66, 56)
# 141.6539943019943
# (225, 65)
# 139.35818621269442
# (104, 61)
# 151.30469534050178
# (155, 60)
# 143.18928144734596
# (217, 63)
# 158.48951562360105
# (365, 102)
# 164.00568853427896
# (564, 104)
# 149.02985534591195
# (530, 100)
# 121.47911338448422
# (34, 23)
# 125.20645363408521
# (38, 28)
# 108.08496732026144
# (17, 24)
# 95.90102171136654
# (18, 29)
# 176.05259026687597
# (98, 26)
# 83.76613616268789
# (26, 29)
# 101.93779761904761
# (40, 28)
# 102.89595500757085
# (67, 23)
# 128.28735632183907
# (58, 27)
# 144.86910774410774
# (66, 24)
# 132.34694989106754
# (51, 24)
# 110.02923602219377
# (71, 22)
# 142.22452265930528
# (63, 23)
# 145.66310541310543
# (52, 27)
# 127.28382352941176
# (34, 20)
# 114.56987847222223
# (32, 24)
# 157.42314814814816
# (30, 24)
# 99.84375
# (32, 21)
# 113.64057142857143
# (70, 25)
# 114.25384615384615
# (26, 25)
# 161.85190097259064
# (29, 26)
# 181.47169384057972
# (64, 23)
# 118.25735294117646
# (34, 20)
# 120.48852657004831
# (46, 24)
# 167.67571533382244
# (47, 29)
# 143.4827441077441
# (36, 22)
# 98.53169934640523
# (51, 20)
# 86.06439393939394
# (22, 24)
# 126.37022397891963
# (22, 23)
# 121.73333333333333
# (65, 20)
# 102.88142857142857
# (56, 25)
# 162.9125
# (40, 24)
# 154.02890159970238
# (112, 128)
# 146.18215174222743
# (453, 147)
# 140.2681567296628
# (633, 135)
# 142.6252741047135
# (602, 151)
# 149.65173867228663
# (260, 146)
# 121.26491045638359
# (577, 125)
# 121.76182316255756
# (215, 133)
# 120.45437089201877
# (568, 125)
# 128.23089430894308
# (328, 120)
# 118.0084524422548
# (557, 129)
# Create 1088 images

# %%
labels = []
image_paths = []

with open("/content/dataset_text_recognition/labels.txt", 'r') as f:
    for label in f:
        label_split = label.split('\t')
        labels.append(label_split[1])
        image_paths.append(label_split[0])

print(labels)
print(image_paths)
# Out:
# ['self\n', 'adhesive\n', 'address\n', 'labels\n', '36\n', '250\n', 'on\n', 'a\n', 'roll\n', 'natwest\n', 'greek\n', 'gastronomy\n', 'cookery\n', 'wines\n', 'local\n', 'toubrs\n', 'specialties\n', 'festive\n', 'recipes\n', 'illustrated\n', '83\n', '73\n', 'the\n', 'house\n', 'of\n', 'the\n', 'spirits\n', 'isabel\n', 'allende\n', 'intensely\n', 'moving\n', 'both\n', 'entertaining\n', 'and\n', 'deeply\n', 'serious\n', 'evening\n', 'standard\n', 'digital\n', 'multimedia\n', 'wiley\n', 'nigel\n', 'chapman\n', 'and\n', 'jenny\n', 'chapman\n', 'software\n', 'design\n', 'for\n', 'systems\n', 'j\n', 'e\n', 'cooling\n', 'nokia\n', 'adapter\n', 'cable\n', 'dlr\n', '3p\n', 'a4382\n', 'nokia\n', '6210\n', 'dlr\n', '3p\n', 'data\n', 'cable\n', 'professional\n', 'issues\n', 'in\n', 'software\n', 'engineering\n', 'frank\n', 'bott\n', 'allison\n', 'coleman\n', 'jack\n', 'eaton\n', 'diane\n', 'rowland\n', 'third\n', 'edition\n', 'silberschatz\n', 'galvin\n', 'operating\n', 'system\n', 'concepts\n', 'fifth\n', 'edition\n', 'systems\n', 'series\n', 'systems\n', 'analysis\n', 'design\n', 'stems\n', 'id\n', 'mason\n', 'leslie\n', 'willcocks\n', 'business\n', 'strategy\n', 'it\n', 'strategy\n', 'information\n', 'wear\n', 's\n', 'alan\n', 'clements\n', 't\n', 'rinciples\n', 'of\n', 'omputer\n', 'hardware\n', 'second\n', 'edition\n', 'software\n', 'engineering\n', 'ian\n', 'sommerville\n', 'sony\n', 'conditions\n', 'handle\n', 'with\n', 'care\n', 'pleaes\n', 'return\n', 'to\n', 'future\n', 'publishing\n', 'ltd\n', 'somerton\n', 'ta11\n', '6tb\n', 'united\n', 'kingdom\n', 'edition\n', 'systems\n', 'database\n', 'an\n', 'introduction\n', 'to\n', 'date\n', 'sixth\n', 'stuart\n', 'russell\n', 'peter\n', 'norvig\n', 'intelligence\n', 'rtificial\n', 'a\n', 'modern\n', 'approach\n', 'essence\n', 'of\n', 'computing\n', 'the\n', 'essence\n', 'of\n', 'artificial\n', 'intelligence\n', 'students\n', 'engineering\n', 'for\n', 'communication\n', 'o\n', 'c\n', 'i\n', 'international\n', 'computer\n', 'science\n', 'series\n', 'discrete\n', 'mathematics\n', 'computer\n', 'for\n', 'scientists\n', 'release\n', 'of\n', 'net\n', 'v10\n', 'marco\n', 'bellinaso\n', 'and\n', 'kevin\n', 'hoffman\n', 'wrox\n', 'wrox\n', 'technical\n', 'support\n', 'at\n', 'support\n', 'wroxcom\n', 'updates\n', 'and\n', 'source\n', 'code\n', 'at\n', 'www\n', 'wroxcom\n', 'wroxcom\n', 'peer\n', 'discussion\n', 'at\n', 'p2p\n', 'programmer\n', 'to\n', 'programmer\n', 'aspnet\n', 'website\n', 'programming\n', 'problem\n', 'design\n', 'solution\n', 'written\n', 'and\n', 'tested\n', 'for\n', 'final\n', 'wolfgang\n', 'emmerich\n', 'engin\n', 'ing\n', 'distributed\n', 'objects\n', 'lights\n', 'marlboro\n', 'autumn\n', 'winter\n', '2001\n', 'argos\n', 'philips\n', 'fisio\n', '820e\n', 'inspiring\n', 'scenes\n', 'the\n', 'edinburg\n', 'festivals\n', 'most\n', 'espmoto\n', 'experience\n', 'the\n', 'revolution\n', 'with\n', 'orange\n', 'to\n', 'order\n', 'your\n', 'v70e\n', 'on\n', 'orange\n', 'please\n', 'call\n', '150\n', 'and\n', 'press\n', 'orange\n', 'summer\n', '2002\n', 'orange\n', 'sounds\n', 'of\n', 'summer\n', 'events\n', 'music\n', 'live\n', 'best\n', 'the\n', 'o\n', 'building\n', 'web\n', 'services\n', 'with\n', 'java\n', 'tm\n', 'making\n', 'sence\n', 'of\n', 'xml\n', 'soap\n', 'wsdl\n', 'and\n', 'uddi\n', 'aircraft\n', 'and\n', 'blast\n', 'can\n', 'cause\n', 'departing\n', 'flying\n', 'injury\n', 'low\n', 'physical\n', 'alligator\n', 'beware\n', 'teeth\n', '115mm\n', 'caution\n', 'height\n', 'proceed\n', 'raised\n', 'when\n', 'with\n', 'beardwell\n', 'construction\n', 'construction\n', 'limited\n', 'maintenance\n', 'refurbishment\n', 'boundary\n', 'road\n', 'stop\n', 'clock\n', 'museum\n', 'tymperleys\n', 'council\n', 'county\n', 'essex\n', 'libraries\n', 'by\n', 'car\n', 'collect\n', 'marks\n', 'spencer\n', 'to\n', 'welcome\n', 'h\n', 'smith\n', 'w\n', 'summer\n', 'high\n', 'lion\n', 'red\n', 'shops\n', 'street\n', 'yard\n', 'summer\n', 'the\n', 'weather\n', 'whatever\n', 'here\n', 'm\n', 't ...
# ['dataset_text_recognition/000000.jpg', 'dataset_text_recognition/000001.jpg', 'dataset_text_recognition/000002.jpg', 'dataset_text_recognition/000003.jpg', 'dataset_text_recognition/000004.jpg', 'dataset_text_recognition/000005.jpg', 'dataset_text_recognition/000006.jpg', 'dataset_text_recognition/000007.jpg', 'dataset_text_recognition/000008.jpg', 'dataset_text_recognition/000009.jpg', 'dataset_text_recognition/000010.jpg', 'dataset_text_recognition/000011.jpg', 'dataset_text_recognition/000012.jpg', 'dataset_text_recognition/000013.jpg', 'dataset_text_recognition/000014.jpg', 'dataset_text_recognition/000015.jpg', 'dataset_text_recognition/000016.jpg', 'dataset_text_recognition/000017.jpg', 'dataset_text_recognition/000018.jpg', 'dataset_text_recognition/000019.jpg', 'dataset_text_recognition/000020.jpg', 'dataset_text_recognition/000021.jpg', 'dataset_text_recognition/000022.jpg', 'dataset_text_recognition/000023.jpg', 'dataset_text_recognition/000024.jpg', 'dataset_text_recognition/000025.jpg', 'dataset_text_recognition/000026.jpg', 'dataset_text_recognition/000027.jpg', 'dataset_text_recognition/000028.jpg', 'dataset_text_recognition/000029.jpg', 'dataset_text_recognition/000030.jpg', 'dataset_text_recognition/000031.jpg', 'dataset_text_recognition/000032.jpg', 'dataset_text_recognition/000033.jpg', 'dataset_text_recognition/000034.jpg', 'dataset_text_recognition/000035.jpg', 'dataset_text_recognition/000036.jpg', 'dataset_text_recognition/000037.jpg', 'dataset_text_recognition/000038.jpg', 'dataset_text_recognition/000039.jpg', 'dataset_text_recognition/000040.jpg', 'dataset_text_recognition/000041.jpg', 'dataset_text_recognition/000042.jpg', 'dataset_text_recognition/000043.jpg', 'dataset_text_recognition/000044.jpg', 'dataset_text_recognition/000045.jpg', 'dataset_text_recognition/000046.jpg', 'dataset_text_recognition/000047.jpg', 'dataset_text_recognition/000048.jpg', 'dataset_text_recognition/000049.jpg', 'dataset_text_recognition/000050.jpg', 'dataset_text_recognition/000051.jpg', 'dataset_text_recognition/000052.jpg', 'dataset_text_recognition/000053.jpg', 'dataset_text_recognition/000054.jpg', 'dataset_text_recognition/000055.jpg', 'dataset_text_recognition/000056.jpg', 'dataset_text_recognition/000057.jpg', 'dataset_text_recognition/000058.jpg', 'dataset_text_recognition/000059.jpg', 'dataset_text_recognition/000060.jpg', 'dataset_text_recognition/000061.jpg', 'dataset_text_recognition/000062.jpg', 'dataset_text_recognition/000063.jpg', 'dataset_text_recognition/000064.jpg', 'dataset_text_recognition/000065.jpg', 'dataset_text_recognition/000066.jpg', 'dataset_text_recognition/000067.jpg', 'dataset_text_recognition/000068.jpg', 'dataset_text_recognition/000069.jpg', 'dataset_text_recognition/000070.jpg', 'dataset_text_recognition/000071.jpg', 'dataset_text_recognition/000072.jpg', 'dataset_text_recognition/000073.jpg', 'dataset_text_recognition/000074.jpg', 'dataset_text_recognition/000075.jpg', 'dataset_text_recognition/000076.jpg', 'dataset_text_recognition/000077.jpg', 'dataset_text_recognition/000078.jpg', 'dataset_text_recognition/000079.jpg', 'dataset_text_recognition/000080.jpg', 'dataset_text_recognition/000081.jpg', 'dataset_text_recognition/000082.jpg', 'dataset_text_recognition/000083.jpg', 'dataset_text_recognition/000084.jpg', 'dataset_text_recognition/000085.jpg', 'dataset_text_recognition/000086.jpg', 'dataset_text_recognition/000087.jpg', 'dataset_text_recognition/000088.jpg', 'dataset_text_recognition/000089.jpg', 'dataset_text_recognition/000090.jpg', 'dataset_text_recognition/000091.jpg', 'dataset_text_recognition/000092.jpg', 'dataset_text_recognition/000093.jpg', 'dataset_text_recognition/000094.jpg', 'dataset_text_recognition/000095.jpg', 'dataset_text_recognition/000096.jpg', 'dataset_text_recognition/000097.jpg', 'dataset_text_recognition/000098.jpg', 'dataset_text_recognition/000099.jpg', 'dataset_text_recognition/000100.jpg', 'dataset_text_recognition/000101.jpg', 'dataset_text_recogni ...

# %%
letters = [char.split('.')[0].lower() for char in labels]
letters = "".join(letters)
letters = sorted(list(set(list(letters))))

chars = "".join(letters)
blank_char = "-"
chars += blank_char
vocab_size = len(chars)

print(f"Size vocab: {vocab_size}")
print(f"Vocab: {chars}")
# Out:
# Size vocab: 38
# Vocab:
# 0123456789abcdefghijklmnopqrstuvwxyz-

# %%
char_to_index = {char:index+1 for index, char in enumerate(sorted(chars))}
index_to_char = {index:char for char, index in char_to_index.items()}

# %%
max_len_label = max([len(label) for label in labels])

def encode(label, char_to_index, max_label_len):
    encoded_labels = torch.tensor(
        [char_to_index[char] for char in label],
        dtype=torch.int32
    )

    lable_lenght = len(encoded_labels)

    lenghts = torch.tensor(
        lable_lenght, dtype=torch.int32
    )

    padded_lables = F.pad(
        encoded_labels,
        (0, max_label_len - lable_lenght),
        value=0
    )

    return lenghts, padded_lables

# %%
def decode(encode_sequences, index_to_char, blank_char="-"):
    decode_sequences = []

    for seq in encode_sequences:
        decode_label = []
        prev_char = None

        for token in seq:
            if token != 0:
                char = index_to_char[token.item()]

                if char != blank_char:
                    if char != prev_char or prev_char == blank_char:
                        decode_label.append(char)

                pre_char = char
        decode_sequences.append("".join(decode_label))

    print(f"From {encode_sequences} to {decode_sequences}")
    return decode_sequences

# %%
data_transform = {
    "train" : transforms.Compose(
        [
            transforms.Resize((100, 420)),
            transforms.ColorJitter(
                brightness=0.5,
                contrast=0.5,
                saturation=0.5
            ),
            transforms.Grayscale(
                num_output_channels=1
            ),
            transforms.GaussianBlur(3),
            transforms.RandomAffine(
                degrees=1,
                shear=1
            ),
            transforms.RandomPerspective(
                distortion_scale=0.3,
                interpolation=3
            ),
            transforms.RandomRotation(
                degrees=2
            ),
            transforms.ToTensor(),
            transforms.Normalize((0.5,), (0.5,))
        ]
    ),

    "val" : transforms.Compose(
        [
            transforms.Resize((100, 420)),
            transforms.Grayscale(1),
            transforms.ToTensor(),
            transforms.Normalize((0.5,), (0.5,))
        ]
    )

}

# %%
val_size = 0.2
test_size = 0.125
random_state = 0
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(
    image_paths, labels,
    test_size=val_size,
    random_state=random_state,
    shuffle=is_shuffle
)

X_train, X_test, y_train, y_test = train_test_split(
    X_train, y_train,
    test_size=test_size,
    random_state=random_state,
    shuffle=is_shuffle
)

print(f"Train: {len(X_train)}")
print(f"Validation: {len(X_val)}")
print(f"Test size: {len(X_test)}")
# Out:
# Train: 761
# Validation: 218
# Test size: 109

# %%
class STRDataset(Dataset):
    def __init__(self, X, y, char_to_index, max_len_label, label_encoder=None, transforms=None):
        self.X = X
        self.y = y
        self.char_to_index = char_to_index
        self.max_len_label = max_len_label
        self.label_encoder = label_encoder
        self.transforms = transforms

    def __len__(self):
        return len(self.X)

    def __getitem__(self, index):
        label = self.y[index]
        image_path = self.X[index]
        image = Image.open(image_path)

        if self.transforms:
            image = self.transforms(image)

        if self.label_encoder:
            len_label, label = self.label_encoder(label, char_to_index, max_len_label)

        return image, label, len_label

# %%
train_dataset = STRDataset(
    X_train, y_train,
    char_to_index,
    max_len_label,
    label_encoder=encode,
    transforms=data_transform['train']
)

val_dataset = STRDataset(
    X_val, y_val,
    char_to_index,
    max_len_label,
    label_encoder=encode,
    transforms=data_transform['val']
)

test_dataset = STRDataset(
    X_test, y_test,
    char_to_index,
    max_len_label,
    label_encoder=encode,
    transforms=data_transform['val']
)

train_batch_size = 64
test_batch_size = 64 * 2

train_loader = DataLoader(
    train_dataset,
    batch_size=train_batch_size,
    shuffle=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=test_batch_size,
    shuffle=False
)

test_loader = DataLoader(
    test_dataset,
    batch_size=test_batch_size,
    shuffle=False
)

# %%
class CRNN(nn.Module):

    def __init__(self, vocab_size, hidden_size, num_layer, unfreeze_layers=3, dropout=0.2):
        super(CRNN, self).__init__()
        backbone = timm.create_model("resnet152", pretrained=True, in_chans=1)
        # Tuong tac voi resnet152 model
        modules = list(backbone.children())[:-2]
        modules.append(nn.AdaptiveAvgPool2d((1, None)))
        self.backbone = nn.Sequential(*modules)

        for para in self.backbone[-unfreeze_layers:].parameters():
            para.requires_grad = True

        self.mapSeq = nn.Sequential(
            nn.Linear(2048, 512),
            nn.ReLU(),
            nn.Dropout(dropout)
        )

        self.GRU = nn.GRU(
            512, hidden_size,
            num_layer,
            dropout=dropout if num_layer > 1 else 0,
            bidirectional=True,
            batch_first=True
        )

        self.layer_norm = nn.LayerNorm(hidden_size*2)

        self.out = nn.Sequential(
            nn.Linear(hidden_size*2, vocab_size),
            nn.LogSoftmax(2)
        )

    def forward(self, x):
        x = self.backbone(x)
        x = x.permute(0, 3, 1, 2)
        x = x.view(x.size(0), x.size(1), -1)
        x = self.mapSeq(x)
        x, _ = self.GRU(x)
        x = self.layer_norm(x)
        x = self.out(x)
        x = x.permute(1, 0, 2)  #based CTC loss
        return x

# %%
hidden_size = 256
num_layer = 3
dropout = 0.2
unfreeze_layer = 3
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Device: {device}")

models = CRNN(vocab_size, hidden_size, num_layer, unfreeze_layer, dropout=dropout).to(device)

# %%
def evaluate(model, dataloader, criterion, device):
    model.eval()
    losses = []

    with torch.no_grad():
        for inputs, labels, label_len in dataloader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            label_len = label_len.to(device)

            output = model(inputs)
            logits_lens = torch.full(
                size=(output.size(1),),
                fill_value=output.size(0),
                dtype=torch.long
            )
            loss = criterion(output, labels, logits_lens, label_len)
            losses.append(loss.item())
    loss = sum(losses) / len(losses)

    return loss

# %%
def train(model, dataloader, criterion, optimizer, scheduler, device, epochs):
    train_losses = []
    val_losses = []

    for epoch in range(epochs):
        start = time.time()

        model.train()
        batch_train_loss = []
        for inputs, labels, labels_len in dataloader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            labels_len = labels_len.to(device)

            optimizer.zero_grad()
            output = model(inputs)

            logits_lens = torch.full(
                size=(output.size(1), ),
                fill_value=output.size(0),
                dtype=torch.long
            )
            loss = criterion(output, labels, logits_lens, labels_len)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 5)
            optimizer.step()

            batch_train_loss.append(loss)

        train_loss = sum(batch_train_loss)/len(batch_train_loss)
        val_loss = evaluate(model, val_loader, criterion, device)

        train_losses.append(train_loss)
        val_losses.append(val_loss)
        print(
            f"EPOCH {epoch + 1}: \tTrain loss {train_loss:.4f} \tValidation loss {val_loss:.4f} \tTime {time.time() - start:.2f} seconds"
        )
        scheduler.step()

    return train_losses, val_losses

# %%
epochs = 100
lr = 5e-4
weight_decay = 1e-4
scheduler_step_size = epochs * 0.5

criterion = nn.CTCLoss(
    blank=char_to_index[blank_char],
    reduction="mean",
    zero_infinity=True
)

optimizer = torch.optim.Adam(
    models.parameters(),
    lr=lr,
    weight_decay=weight_decay,
)

scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer,
    step_size=scheduler_step_size,
    gamma=0.1
)

# %%
train_losses, val_losses = train(models, train_loader, criterion, optimizer, scheduler, device, epochs)
# Out:
# EPOCH 1: 	Train loss 3.6159 	Validation loss 2.9756 	Time 7.83 seconds
# EPOCH 2: 	Train loss 2.8239 	Validation loss 2.8151 	Time 5.80 seconds
# EPOCH 3: 	Train loss 2.6675 	Validation loss 2.7326 	Time 5.64 seconds
# EPOCH 4: 	Train loss 2.4844 	Validation loss 2.4643 	Time 5.64 seconds
# EPOCH 5: 	Train loss 2.2273 	Validation loss 2.3105 	Time 5.68 seconds
# EPOCH 6: 	Train loss 1.9405 	Validation loss 1.9031 	Time 5.76 seconds
# EPOCH 7: 	Train loss 1.5690 	Validation loss 1.5759 	Time 5.76 seconds
# EPOCH 8: 	Train loss 1.1738 	Validation loss 1.2897 	Time 5.65 seconds
# EPOCH 9: 	Train loss 0.8713 	Validation loss 1.0361 	Time 5.76 seconds
# EPOCH 10: 	Train loss 0.6927 	Validation loss 0.9766 	Time 5.68 seconds
# EPOCH 11: 	Train loss 0.5678 	Validation loss 0.8655 	Time 5.80 seconds
# EPOCH 12: 	Train loss 0.4592 	Validation loss 0.7623 	Time 5.60 seconds
# EPOCH 13: 	Train loss 0.4014 	Validation loss 0.7141 	Time 5.86 seconds
# EPOCH 14: 	Train loss 0.3462 	Validation loss 0.6520 	Time 5.63 seconds
# EPOCH 15: 	Train loss 0.2836 	Validation loss 0.7440 	Time 5.71 seconds
# EPOCH 16: 	Train loss 0.2518 	Validation loss 0.7116 	Time 5.68 seconds
# EPOCH 17: 	Train loss 0.2581 	Validation loss 0.6567 	Time 5.79 seconds
# EPOCH 18: 	Train loss 0.2345 	Validation loss 0.6965 	Time 5.68 seconds
# EPOCH 19: 	Train loss 0.1935 	Validation loss 0.7183 	Time 5.75 seconds
# EPOCH 20: 	Train loss 0.1655 	Validation loss 0.7063 	Time 5.74 seconds
# EPOCH 21: 	Train loss 0.1750 	Validation loss 0.7973 	Time 5.93 seconds
# EPOCH 22: 	Train loss 0.1578 	Validation loss 0.7757 	Time 5.74 seconds
# EPOCH 23: 	Train loss 0.1636 	Validation loss 0.6386 	Time 5.96 seconds
# EPOCH 24: 	Train loss 0.1649 	Validation loss 0.6938 	Time 5.64 seconds
# EPOCH 25: 	Train loss 0.1193 	Validation loss 0.7922 	Time 5.86 seconds
# EPOCH 26: 	Train loss 0.1223 	Validation loss 0.6608 	Time 5.68 seconds
# EPOCH 27: 	Train loss 0.1184 	Validation loss 0.6524 	Time 5.77 seconds
# EPOCH 28: 	Train loss 0.1285 	Validation loss 0.7421 	Time 5.66 seconds
# EPOCH 29: 	Train loss 0.1277 	Validation loss 0.6203 	Time 5.88 seconds
# EPOCH 30: 	Train loss 0.1077 	Validation loss 0.7128 	Time 5.64 seconds
# EPOCH 31: 	Train loss 0.1296 	Validation loss 0.6441 	Time 5.80 seconds
# EPOCH 32: 	Train loss 0.1122 	Validation loss 0.6874 	Time 5.62 seconds
# EPOCH 33: 	Train loss 0.0933 	Validation loss 0.5843 	Time 5.89 seconds
# EPOCH 34: 	Train loss 0.1022 	Validation loss 0.6833 	Time 5.62 seconds
# EPOCH 35: 	Train loss 0.0936 	Validation loss 0.6660 	Time 5.70 seconds
# EPOCH 36: 	Train loss 0.0824 	Validation loss 0.6231 	Time 5.71 seconds
# EPOCH 37: 	Train loss 0.0877 	Validation loss 0.6903 	Time 5.71 seconds
# EPOCH 38: 	Train loss 0.0993 	Validation loss 0.6747 	Time 5.80 seconds
# EPOCH 39: 	Train loss 0.0943 	Validation loss 0.5938 	Time 5.70 seconds
# EPOCH 40: 	Train loss 0.1417 	Validation loss 0.6885 	Time 5.68 seconds
# EPOCH 41: 	Train loss 0.1054 	Validation loss 0.6561 	Time 5.69 seconds
# EPOCH 42: 	Train loss 0.1128 	Validation loss 0.6298 	Time 5.89 seconds
# EPOCH 43: 	Train loss 0.1065 	Validation loss 0.5908 	Time 5.60 seconds
# EPOCH 44: 	Train loss 0.0895 	Validation loss 0.5613 	Time 5.76 seconds
# EPOCH 45: 	Train loss 0.0817 	Validation loss 0.6350 	Time 5.75 seconds
# EPOCH 46: 	Train loss 0.0736 	Validation loss 0.6192 	Time 5.72 seconds
# EPOCH 47: 	Train loss 0.0836 	Validation loss 0.5618 	Time 5.63 seconds
# EPOCH 48: 	Train loss 0.0847 	Validation loss 0.6236 	Time 5.89 seconds
# EPOCH 49: 	Train loss 0.0723 	Validation loss 0.6020 	Time 5.64 seconds
# EPOCH 50: 	Train loss 0.0718 	Validation loss 0.5802 	Time 5.83 seconds
# EPOCH 51: 	Train loss 0.0425 	Validation loss 0.5820 	Time 5.69 seconds
# EPOCH 52: 	Train loss 0.0393 	Validation loss 0.5840 	Time 5.82 seconds
# EPOCH 53: 	Train loss 0.0370 	Validation loss 0.5830 	Time 5.67 seconds
# EPOCH 54: 	Train loss 0.0415 	Validation loss 0.5843 	Time 5.71 seconds
# EPOCH 55: 	Train loss 0.0302 	Validation loss 0.5793 	Time 5.61 seconds
# EPOCH 56: 	Train loss 0.0464 	Validation loss 0.5647 	Time 5.73 seconds
# EPOCH 57: 	Train loss 0.0436 	Validation loss 0.5610 	Time 5.65 seconds
# EPOCH 58: 	Train loss 0.0304 	Validation loss 0.5609 	Time 5.74 seconds
# EPOCH 59: 	Train loss 0.0435 	Validation loss 0.5529 	Time 5.68 seconds
# EPOCH 60: 	Train loss 0.0336 	Validation loss 0.5446 	Time 5.79 seconds
# EPOCH 61: 	Train loss 0.0345 	Validation loss 0.5416 	Time 5.67 seconds
# EPOCH 62: 	Train loss 0.0291 	Validation loss 0.5404 	Time 5.70 seconds
# EPOCH 63: 	Train loss 0.0395 	Validation loss 0.5412 	Time 5.81 seconds
# EPOCH 64: 	Train loss 0.0354 	Validation loss 0.5464 	Time 5.79 seconds
# EPOCH 65: 	Train loss 0.0277 	Validation loss 0.5451 	Time 5.72 seconds
# EPOCH 66: 	Train loss 0.0463 	Validation loss 0.5419 	Time 5.71 seconds
# EPOCH 67: 	Train loss 0.0195 	Validation loss 0.5430 	Time 5.79 seconds
# EPOCH 68: 	Train loss 0.0318 	Validation loss 0.5439 	Time 5.64 seconds
# EPOCH 69: 	Train loss 0.0289 	Validation loss 0.5462 	Time 5.93 seconds
# EPOCH 70: 	Train loss 0.0277 	Validation loss 0.5481 	Time 5.75 seconds
# EPOCH 71: 	Train loss 0.0270 	Validation loss 0.5508 	Time 5.80 seconds
# EPOCH 72: 	Train loss 0.0269 	Validation loss 0.5393 	Time 5.65 seconds
# EPOCH 73: 	Train loss 0.0291 	Validation loss 0.5357 	Time 5.91 seconds
# EPOCH 74: 	Train loss 0.0286 	Validation loss 0.5361 	Time 5.67 seconds
# EPOCH 75: 	Train loss 0.0250 	Validation loss 0.5358 	Time 5.76 seconds
# EPOCH 76: 	Train loss 0.0222 	Validation loss 0.5359 	Time 5.69 seconds
# EPOCH 77: 	Train loss 0.0257 	Validation loss 0.5427 	Time 5.88 seconds
# EPOCH 78: 	Train loss 0.0171 	Validation loss 0.5407 	Time 5.63 seconds
# EPOCH 79: 	Train loss 0.0280 	Validation loss 0.5348 	Time 5.79 seconds
# EPOCH 80: 	Train loss 0.0315 	Validation loss 0.5307 	Time 5.71 seconds
# EPOCH 81: 	Train loss 0.0240 	Validation loss 0.5376 	Time 5.80 seconds
# EPOCH 82: 	Train loss 0.0267 	Validation loss 0.5545 	Time 5.67 seconds
# EPOCH 83: 	Train loss 0.0387 	Validation loss 0.5456 	Time 5.83 seconds
# EPOCH 84: 	Train loss 0.0266 	Validation loss 0.5330 	Time 5.68 seconds
# EPOCH 85: 	Train loss 0.0282 	Validation loss 0.5442 	Time 5.82 seconds
# EPOCH 86: 	Train loss 0.0316 	Validation loss 0.5426 	Time 5.71 seconds
# EPOCH 87: 	Train loss 0.0261 	Validation loss 0.5401 	Time 5.80 seconds
# EPOCH 88: 	Train loss 0.0369 	Validation loss 0.5340 	Time 5.68 seconds
# EPOCH 89: 	Train loss 0.0306 	Validation loss 0.5254 	Time 5.81 seconds
# EPOCH 90: 	Train loss 0.0185 	Validation loss 0.5303 	Time 5.76 seconds
# EPOCH 91: 	Train loss 0.0278 	Validation loss 0.5271 	Time 5.81 seconds
# EPOCH 92: 	Train loss 0.0244 	Validation loss 0.5204 	Time 5.72 seconds
# EPOCH 93: 	Train loss 0.0254 	Validation loss 0.5136 	Time 5.73 seconds
# EPOCH 94: 	Train loss 0.0248 	Validation loss 0.5244 	Time 5.72 seconds
# EPOCH 95: 	Train loss 0.0234 	Validation loss 0.5165 	Time 5.66 seconds
# EPOCH 96: 	Train loss 0.0198 	Validation loss 0.5225 	Time 5.68 seconds
# EPOCH 97: 	Train loss 0.0239 	Validation loss 0.5251 	Time 5.67 seconds
# EPOCH 98: 	Train loss 0.0192 	Validation loss 0.5241 	Time 5.82 seconds
# EPOCH 99: 	Train loss 0.0210 	Validation loss 0.5225 	Time 5.70 seconds
# EPOCH 100: 	Train loss 0.0212 	Validation loss 0.5317 	Time 6.01 seconds

# %%
torch.save(models.state_dict(), "/content/text_recognition.pt")
